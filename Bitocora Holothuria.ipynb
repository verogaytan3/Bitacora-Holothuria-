# %% [markdown]
# # Identificación Genética de Pepino de mar presente en Tecolutla, Veracruz

# %% [markdown]
# ### Presenta: Gaytan Dominguez Veronica Guadalupe

# %% [markdown]
# Directora:Xóchitl Guzmán García

# %% [markdown]
# Asesores: Jhoana Diaz Larrea, Miguel Ángel del Rio Portillo

# %% [markdown]
# ![Picture1.jpg](attachment:Picture1.jpg)

# %% [markdown]
# # Ubicación taxonómica

# %% [markdown]
# * Dominio : Eukaryota
#
# 2. Reino   : Animalia
#
# 3. Phylum  : Echinodermata
#
# 4. Clase   : Holothuria
#
# 5. Especie : Grisea

# %% [markdown]
# # Objetivo

# %% [markdown]
# * Realizar Identificación genética del pepino de mar a través de la obtención de secuencia de genes 16S y COI.

# %% [markdown]
# # Materiales y métodos

# %% [markdown]
# 1. Extracción de ADN Kit PROMEGA
#
# 2. Amplificación PCR
#
# 3. Electroforesis en gel de agarosa 1%
#
# 4. Purificación ADN, Kit PROMEGA 16S
#
# 5. Productos enviados a secuenciar

# %% [markdown]
# # 1) Extracción de ADN

# %% [markdown]
# * Se diseccionaron los pies ambulacrales de 2 ejemplares de pepino de mar , aproximadamente 5 gr.
# * Debido a que en los pies ambulacrales había mas cantidad de musculo.

# %% [markdown]
# ![Picture6.jpg](attachment:Picture6.jpg) ![Picture5.jpg](attachment:Picture5.jpg)

# %% [markdown]
# # 2) Amplificación PCR

# %% [markdown]
# ![Picture11.png](attachment:Picture11.png)

# %% [markdown]
# ### *Primers Utilizados

# %% [markdown]
# ![Picture12.png](attachment:Picture12.png)

# %% [markdown]
# ### * Ciclo de PCR Gen 16S

# %% [markdown]
# ![Picture13.png](attachment:Picture13.png)

# %% [markdown]
# # 3) Cuantificación

# %% [markdown]
# ![Picture7.png](attachment:Picture7.png)

# %% [markdown]
# ![Picture9.png](attachment:Picture9.png)

# %% [markdown]
# # 4) Electroforesis. ADN Extraído

# %% [markdown]
# Se muestra que hay una buena concentración de ADN

# %% [markdown]
# ![Picture14.png](attachment:Picture14.png)

# %% [markdown]
# # 5) Electroforesis de PCR. Gen 16S

# %% [markdown]
# ![Picture15.png](attachment:Picture15.png)

# %% [markdown]
# # 6) Purificación. Gen 16S

# %% [markdown]
# ![Picture16.png](attachment:Picture16.png)

# %% [markdown]
# # 7) Purificados enviados a secuenciar
